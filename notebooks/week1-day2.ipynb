# %%
from openai import OpenAI

# %%
# using local llm - ollama
# no need ot load api keys
base_url = "http://localhost:11434/v1"
api_key = "ollama"

ollama_client = OpenAI(base_url=base_url, api_key=api_key)

# %%
MODEL_NAME="phi3"
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What is the capital of India?"}
]

# %%
response = ollama_client.chat.completions.create(
    model=MODEL_NAME,
    messages=messages
)
print(response.choices[0].message.content)
# Out:
# The capital of India is New Delhi. It serves as the seat of the federal government and is one of the most prominent cities in South Asia, known for its historical landmarks like the Rashtrapati Bhavan (the parliament building) and the India Gate military cenotaph monument. The city was designed by British architects Herbert Baker and Edwin Lutyens during colonial times but took on a life of its own with Indian influence, becoming an amalgamation that reflects both European sensibty in urban planning as well as traditional aspects central to India's heritage. New Delhi is also home to the Red Fort (Lal Qila), which was once inhabited by Mughal emperors and now functions largely for touristic purposes due to its significant historical importance, exemplifying a blend of various architectural influences throughout Indian history including Islamic, Persian, and European styles. Additionally, understanding New Delhi as the political heart allows one to appreciate how it is also central in
# ...

# %%
### Behind the OpenAI library
import requests

# %%
headers = {
    "Authorization": f"Bearer {api_key}",
    "Content-Type": "application/json"
}

payload = {
    "model": MODEL_NAME,
    "messages": messages
}

chat_url = "http://localhost:11434/v1/chat/completions"
response = requests.post(url=chat_url, json=payload, headers=headers)
response.json()
response.json()['choices'][0]['message']['content']
# Out:
# "The capital of India is New Delhi. It serves as both the seat of central government and administrative center of Delhi, which has been one of Europe' enduring civilizations for several thousand years (the Indus Valley Civilization). However, it was not until January 1950 that Chandigarh—a union territory in north India designed by renowned architect Le Corbusier—was officially established as the planned capital city. New Delhi is a part of this Union Territory and houses all three branches of government along with numerous museums, historical sites, high end shopping centers, and entertainment destinations such as multiplexes and restaurants across several districts within it."
